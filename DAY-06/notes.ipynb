# %% [markdown]
# ## Functions

# %%
n=3
s="Manoj"
for i in range(n):
    print(s)
# Out:
# Manoj
# Manoj
# Manoj

# %%
n=3
s="Arun"
for i in range(n):
    print(s)
# Out:
# Arun
# Arun
# Arun

# %%
n=3
s="Pradeep"
for i in range(n):
    print(s)
# Out:
# Pradeep
# Pradeep
# Pradeep

# %%
n=4
s="Python"
for i in range(n):
    print(s)
# Out:
# Python
# Python
# Python
# Python

# %%
def fun():
    print("hello")

# %%
fun()
# Out:
# hello

# %%
def rocky_bhai():
    for i in range(5):
        print("Voilance....")

# %%
rocky_bhai()
# Out:
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....

# %%
def rocky_bhai(n):
    for i in range(n):
        print("Voilance....")

# %%
rocky_bhai(5)
# Out:
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....

# %%
def rocky_bhai(n):
    for i in range(n):
        print("Voilance....")

print("Danger.....")
rocky_bhai(5)
# Out:
# Danger.....
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....

# %%
def rocky_bhai():
    for i in range(1):
        print("Voilance....")

print("Danger.....")
rocky_bhai(5)
# Out:
# Danger.....
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 6
#       3         print("Voilance....")
#       5 print("Danger.....")
# ----> 6 rocky_bhai(5)
#
# TypeError: rocky_bhai() takes 0 positional arguments but 1 was given

# %%
def rocky_bhai(n):
    for i in range(n):
        print("Voilance....")

print("Danger.....")
rocky_bhai(5)
print("Adheera your dead..")
rocky_bhai(10)
# Out:
# Danger.....
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Adheera your dead..
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....
# Voilance....

# %%
def rocky_bhai(n,s):
    for i in range(n):
        print("Voilance....")
        print(s)

print("Danger.....")
rocky_bhai(1,"i dont like voilance")
print("Adheera your dead..")
# rocky_bhai(10)
# Out:
# Danger.....
# Voilance....
# i dont like voilance
# Adheera your dead..

# %%
print(rocky_bhai(n,s))
# Out:
# Voilance....
# Python
# Voilance....
# Python
# Voilance....
# Python
# Voilance....
# Python
# None

# %%
def rocky_bhai(n,s):
    for i in range(n):
        print("Voilance....")
    return 8

rocky_bhai(1,"i dont like voilance")
# Out:
# Voilance....
# 8

# %%
def fun():
    return 8

fun()
# Out:
# 8

# %%
def fun():
    return 8

rocky=fun()
print(rocky)
# Out:
# 8

# %%
def fun(n):
    return n

rocky=fun(8)
print(rocky)
# Out:
# 8

# %%
def fun(n):
    return n * 6

rocky=fun(8)
print(rocky)
# Out:
# 48

# %%
def fun(n):
    return n

rocky=fun("Manoj")
print(rocky)
# Out:
# Manoj

# %%
# Printing the table

def table(n):
    for i in range(1,11):
        print(f"{n} X {i} = {n*i}")
    
table(5)
# Out:
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
table(10)
# Out:
# 10 X 1 = 10
# 10 X 2 = 20
# 10 X 3 = 30
# 10 X 4 = 40
# 10 X 5 = 50
# 10 X 6 = 60
# 10 X 7 = 70
# 10 X 8 = 80
# 10 X 9 = 90
# 10 X 10 = 100

# %%
def table(n):
    for i in range(1,11):
        print(str(n)+"*"str(i)"=="str(n*i))
    
table(5)
# Out:
#   Cell In[41], line 3
#     print(str(n)+"*"str(i)"=="str(n*i))
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
def table(n):
    for i in range(1,11):
         print(str(n) + " * " + str(i) + " = " + str(n * i))
    
table(5)
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
