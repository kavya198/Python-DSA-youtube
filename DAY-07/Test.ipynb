# %%
diff = 10-20
print(abs(diff))
# Here "abs" means 'absoulte value' when 2 numbers are compared irrespective of the value of the numbers with which it is operated first
# Out:
# 10

# %%
hi="b"
print(ord(hi))
# Here "ord" means 'ordinal value' for the letter assigned to an object
# Out:
# 98
