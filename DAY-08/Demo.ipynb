# %%
#def finalValueAfterOperations(self, operations: List[str]) -> int:
operations = ["X++","++X","X++"]
X=0
for i in operations:
        if i == "X++" or i == "++X":
            X+=1
        if i == "X--" or i == "X--":
            X-=1
print(X)
# Out:
# 3
