# %% [markdown]
# # Operators
#
# ## Arthimetic operators
# - additon (+)
# - substraction (-)
# - multiplication (*)
# - division (/)
# - floor division (//)
# - modulus (%)
# - exponentiation (**)
#
# ## Comparasion operators
# - Equal to
# - Not Equal to
# - greater than
# - less tha
# - Greater than or equal to
# - less than or equal
#
# ## Logical operators
# - AND
# - OR
# - NOT

# %%
a=20
b=10

# %%
# Addition
add_result = a+b
print(add_result)

# %%
# substractions
sub_result= a - b
print(sub_result)

# %%
# multiplication
mul_result = a*b
print(mul_result)

# %%
# division
div_result = a/b
print(div_result)

# %%
## floor division
div_result = a//b
print(div_result)

# %%
a=21
b=2

a/b

# %%
a//b

# %%
a%b

# %%
a**b

# %%
# comparsion operators
# == Equals to operator
a=10
b=10

a==b

# %%
a=10
b=20

a==b

# %%
a=10
b=20

a!=b

# %%
age1=20
age2=30

age1>age2

# %%
age1=20
age2=30

age1<age2

# %%
age1=20
age2=30

age1<=age2

# %%
age1=30
age2=30

age1>=age2

# %%
#logical operators

# and
X=False
Y=True
result =X and Y
print(result)
# Out:
# False

# %%
#logical operators

# and
X=True
Y=True
result=X and Y
print(result)
# Out:
# True

# %%
# or
X=True
Y=False
result=X or Y
print(result)
# Out:
# True

# %%
# or
X=False
Y=False
result=X or Y
print(result)
# Out:
# False

# %%
#NOT

# %%
# Simple calaculator

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2


print("Addition: ", addition)   
print("Susubtraction",subtraction)
print("multiplication",multiplication)
print("division",division)
print("floor division",floor_division)
print("modulus",modulus)
print("exponentiation",exponentiation)

# %%
# Simple calaculator

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2


print("Addition: ", addition)   
print("Susubtraction",subtraction)
print("multiplication",multiplication)
print("division",division)
print("floor division",floor_division)
print("modulus",modulus)
print("exponentiation",exponentiation)

# %%
# Simple calaculator

num2 = float(input("Enter the first number: "))
num3 = float(input("Enter the second number: "))

addition = num2 + num3
subtraction = num2 - num3
multiplication = num2 * num3
division = num2 / num3
floor_division = num2 // num3
modulus = num2 % num3
exponentiation = num2 ** num3


print("addition: ", addition)   
print("subtraction",subtraction)
print("multiplication",multiplication)
print("division",division)
print("floor division",floor_division)
print("modulus",modulus)
print("exponentiation",exponentiation)

# %%
x=False
not x
# Out:
# True

# %%
# Simple calaculator

num2 = float(input("Enter the first number: "))
num3 = float(input("Enter the second number: "))

addition = num2 + num3
subtraction = num2 - num3
multiplication = num2 * num3
division = num2 / num3
floor_division = num2 // num3
modulus = num2 % num3
exponentiation = num2 ** num3


print("addition: ", addition)   
print("subtraction",subtraction)
print("multiplication",multiplication)
print("division",division)
print("floor division",floor_division)
print("modulus",modulus)
print("exponentiation",exponentiation)
# Out:
# addition:  14.0
# subtraction -4.0
# multiplication 45.0
# division 0.5555555555555556
# floor division 0.0
# modulus 5.0
# exponentiation 1953125.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Simple calaculator
# ----> 3 num2 = float(input("Enter the first number: "))
#       4 num3 = float(input("Enter the second number: "))
#       6 addition = num2 + num3
#
# File d:\MicroDegree\New folder\Python-DSA-youtube\pythonclass-py-3.12.0\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File d:\MicroDegree\New folder\Python-DSA-youtube\pythonclass-py-3.12.0\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
