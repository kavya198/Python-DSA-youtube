# %% [markdown]
# - Print
# - Variables
# - Indedations
# - If Loop

# %%
print("Hi ITKannadigaree")
# Out:
# Hi ITKannadigaree

# %%
## Varibles

print("Hi Kichhaa")
# Out:
# Hi Kichhaa

# %%
PowerStar="Puneeth_RajKumar"

print(PowerStar)
# Out:
# Puneeth_RajKumar

# %%
type(PowerStar)
# Out:
# str

# %%
print(Kichha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(Kichha)
#
# NameError: name 'Kichha' is not defined

# %%
Kichha="sudeep"
print(Kichha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Kichha=sudeep
#       2 print(Kichha)
#
# NameError: name 'sudeep' is not defined

# %%
Kichha="sudeepp"
print(Kichha)
# Out:
# sudeepp

# %%
Rocking_star=1
Print(Rocking_star)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 Rocking_star=1
# ----> 2 Print(Rocking_star)
#
# NameError: name 'Print' is not defined

# %%
Rocking_star=2
print(Rocking_star)
# Out:
# 2

# %%
print(Rocking_star+1)
# Out:
# 2

# %%
Rocking_star='1'
print(Rocking_star+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 Rocking_star='1'
# ----> 2 print(Rocking_star+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
Rocking_star='1'
print(Rocking_star+'1')
# Out:
# 11

# %%
Rocking_star='1'
print(Rocking_star+'3')
# Out:
# 13

# %%
type(Rocking_star)
# Out:
# str

# %%
Rocking_star=1
print(Rocking_star+7)
# Out:
# 8

# %%
type(Rocking_star)
# Out:
# int

# %%
a=10
print("Manoj"*a)
# Out:
# ManojManojManojManojManojManojManojManojManojManoj

# %%
type(a)
# Out:
# int

# %%
a=3
print("Manoj"*a)
# Out:
# ManojManojManoj

# %%
if 1+2 == 3:
    print("This is right..")
# Out:
# This is right..

# %%
if 1+2 == 4:
    print("This is right..")

# %%
if 1+2 == 4:
    print("This is right..")
else:
    print("This is not right..")
# Out:
# This is not right..

# %%
if 1+2==3:
print("this is wrong..")
# Out:
#   Cell In[24], line 2
#     print("this is wrong..")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if 1+2==3:
 print("this is wrong..")
# Out:
# this is wrong..

# %%
if 1+2==3:
    print("this is wrong..")
# Out:
# this is wrong..

# %%
if 1+2==3:
    print("this is wrong..")
print("this is right")
# Out:
# this is wrong..
# this is right

# %%
if 1+2==4:
    print("this is wrong..")
print("this is right")
# Out:
# this is right

# %%
if 1+2==4:
    print("this is wrong..")
    print("this is right")

# %%
if 1+2==4:
    print("this is wrong..")
print("this is right")
else:
    print("this is test")
# Out:
#   Cell In[31], line 4
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
if 1+2==4:
    print("this is right..")
else:
    print("this is wrong")

print("this is test")
# Out:
# this is wrong
# this is test

# %%
if 1+2==3:
    print("this is right..")
else:
    print("this is wrong")

print("this is test")

print("this is test indendation")
# Out:
# this is right..
# this is test
# this is test indendation

# %%
if 1+2==4:
    print("this is right..")
else:
    print("this is wrong")

print("this is test")

    print("this is test indendation")
# Out:
#   Cell In[35], line 8
#     print("this is test indendation")
#     ^
# IndentationError: unexpected indent

# %%
if 1+2==4:
    print("this is right..")
else:
    print("this is wrong")

print("this is test")

print("this is test indendation")
# Out:
# this is wrong
# this is test
# this is test indendation

# %%
Movie="English"

if Movie == 'English':
    print("Am not going on today...")
else:
    print("I will tomo")
# Out:
# Am not going on today...

# %%
Movie="Kannada"

if Movie == 'English':
    print("Am not going on today...")
else:
    print("I will go today")
# Out:
# I will go today

# %%
gender="girl"

if gender=="boy":
    print("Go right side...")
else:
    print("Go Left side...")
# Out:
# Go Left side...
